# %%
from models.classical_model import ClassicDetector
from models.sstw_tracker import SSTWTracker
from ultralytics import YOLO

# %%
classical_detector = ClassicDetector('../../training/svm_sstw/scaler.onnx', '../../training/svm_sstw/ovr_linear_svc.onnx')
classical_tracker = SSTWTracker('../../datasets', '../../outputs/svm', classical_detector)
# Out:
# c:\Users\ASUS\anaconda3\envs\cv_fix_base\lib\site-packages\deep_sort_realtime\embedder\embedder_clip.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
yolo_detector = YOLO('../../training/yolo_sstw/weights/best-fp32.onnx', task='detect')
yolo_tracker = SSTWTracker('../../datasets', '../../outputs/yolo', yolo_detector)

# %%
# classical_tracker(['Four_Way_Intersection_Video_Generation.mp4'])
yolo_tracker([
  'Four_Way_Intersection_Video_Generation.mp4',
  'Surveillance Camera Footage.mp4',
  "When My City's Traffic Lights Turn Off __ ViralHog.mp4"
])
# Out:
# Processed 30 frames.
# Processed 60 frames.
# Processed 90 frames.
# Processed 120 frames.
# Processed 150 frames.
# Processed 180 frames.
# Video saved to: outputs/yolo\out_Four_Way_Intersection_Video_Generation.mp4
# Total frames processed: 192
# Processed 30 frames.
# Processed 60 frames.
# Processed 90 frames.
# Processed 120 frames.
# Processed 150 frames.
# Processed 180 frames.
# Processed 210 frames.
# Processed 240 frames.
# Processed 270 frames.
# Processed 300 frames.
# Processed 330 frames.
# Processed 360 frames.
# Processed 390 frames.
# Processed 420 frames.
# Processed 450 frames.
# Processed 480 frames.
# Processed 510 frames.
# Processed 540 frames.
# Processed 570 frames.
# Processed 600 frames.
# Processed 630 frames.
# Processed 660 frames.
# Processed 690 frames.
# Processed 720 frames.
# Processed 750 frames.
# Processed 780 frames.
# Processed 810 frames.
# Processed 840 frames.
# Processed 870 frames.
# Processed 900 frames.
# Processed 930 frames.
# ...
